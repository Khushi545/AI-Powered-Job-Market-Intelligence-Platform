# %%
import pandas as pd
jobs = pd.read_csv("../data/jobs_with_skills_v2.csv")
print(jobs.columns.tolist())
print(jobs.dtypes)
# Out:
# ['job_id', 'company_name', 'title', 'description', 'location', 'formatted_work_type', 'formatted_experience_level', 'min_salary', 'max_salary', 'med_salary', 'currency', 'remote_allowed', 'skills_desc', 'clean_description', 'clean_title', 'extracted_skills', 'skill_count']
# job_id                          int64
# company_name                      str
# title                             str
# description                       str
# location                          str
# formatted_work_type               str
# formatted_experience_level        str
# min_salary                    float64
# max_salary                    float64
# med_salary                    float64
# currency                          str
# remote_allowed                float64
# skills_desc                       str
# clean_description                 str
# clean_title                       str
# extracted_skills                  str
# skill_count                     int64
# dtype: object

# %%
jobs = pd.read_csv("../data/job_skills.csv")
print(jobs.columns.tolist())
print(jobs.dtypes)
# Out:
# ['job_id', 'skill']
# job_id    int64
# skill       str
# dtype: object

# %%
jobs = pd.read_csv("../data/skills/skills_master.csv")
print(jobs.columns.tolist())
print(jobs.dtypes)
# Out:
# ['skill', 'category']
# skill       str
# category    str
# dtype: object

# %%
jobs = pd.read_csv("../data/skills/skill_aliases.csv")
print(jobs.columns.tolist())
print(jobs.dtypes)
# Out:
# ['alias', 'normalized_skill']
# alias               str
# normalized_skill    str
# dtype: object
